# %% [markdown]
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## David Fogelman

# %% [markdown]
# ___
# ## Introdução
#
# O meu objetivo do projeto é definir a relção da escolaridade com o acesso da internet e a renda
#
# https://tecnologia.uol.com.br/noticias/redacao/2015/04/29/ibge-renda-e-escolaridade-tem-relacao-direta-com-acesso-a-internet.htm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline



print('Esperamos trabalhar no diretório')
print(os.getcwd())
print("ok")
# Out:
# Esperamos trabalhar no diretório
# E:\Semestre 2\Ciência dos Dados\Projetos\InsperEng-CD
# ok

# %%
dados = pd.read_csv('Dados_selecionados.csv')

lista = ["UF", "V8005", "V06111", "V4750", "V4745"]
dados = dados.loc[:,lista]

# %%
dados_not_null = dados[pd.notnull(dados.UF)&pd.notnull(dados.V8005)&pd.notnull(dados.V06111)&pd.notnull(dados.V4750)&pd.notnull(dados.V4745)]
dados_not_null = dados_not_null[dados.V4750!=999999999999] # tirando rendas inválidas

dados_not_null = dados_not_null[dados.V4745!=8] # tirando ensinos inderteminados

# naonulos13 = naonulos13[dados13.V4614!=999999999999]
# dados_not_null = dados[pd.notnull(dados.V4745)]
# dados.UF.describe()
# dados_not_null.describe()
dados = dados_not_null

dados.V06111 = dados.V06111.astype('category')
dados.V06111.cat.categories = (['Sim', 'Não'])
dados.V4745 = dados.V4745.astype('category')
dados.V4745.cat.categories = (['Sem instrução','Fundamental incompleto ou equivalente','Fundamental completo ou equivalente','Médio incompleto ou equivalente','Médio completo ou equivalente','Superior incompleto ou equivalente','Superior completo' ])

# %%
ct1 = pd.crosstab(dados.V06111, dados.V4745)
ct1.plot(kind='bar', color=('red','blue','green','yellow', 'salmon'),figsize=(20, 5))
plt.ylabel('Frequência Absoluta')
plt.title("Nivel de Ensino pelo uso de Internet \nem um período de 12 mêses")

# %%
ct1 = pd.crosstab(dados.V06111, dados.V4745)
ct1.plot(kind='pie',subplots = True,figsize=(30, 5),autopct="%0.2f")
# plt.ylabel('Frequência Absoluta')

plt.title("Nivel de Ensino pelo uso de Internet \nem um período de 12 mêses")

# %%
# # dados.V4750.describe()
# # bp = dados.V4750.boxplot()
# plot = dados.V4750.plot(kind='box',title='Expectativa de vida de países do mundo')#, color='red')
# plt.ylabel('(em anos)')
# plt.xlabel('Ano')

# %%
# # pd.cut() quanti para a quali

# Renda_parc = dados[dados.V4750<5000] # tirando rendas inválidas

# ct2 = Renda_parc.V4750.plot.hist(stacked=False)
# ct2.plot()


# pd.crosstab(Renda_parc.V06111, Renda_parc.V4750)

# %%
pd.crosstab(dados.V06111, dados.V4745)
# Out:
# V4745   Sem instrução  Fundamental incompleto ou equivalente  \
# V06111
# Sim              1965                                  39044
# Não             23254                                  66397
#
# V4745   Fundamental completo ou equivalente  Médio incompleto ou equivalente  \
# V06111
# Sim                                   16938                            16663
# Não                                   12953                             5436
#
# V4745   Médio completo ou equivalente  Superior incompleto ou equivalente  \
# V06111
# Sim                             56770                               13657
# Não                             17053                                 771
#
# V4745   Superior completo
# V06111
# Sim                 27717
# Não                  2250

# %%
pd.crosstab(dados.V06111,  dados.V4750 )
# Out:
# V4750   0.0       5.0       6.0       7.0       8.0       10.0      11.0      \
# V06111
# Sim         1747         0         1         1        12         7         6
# Não         1019         1         1         3         9        13         8
#
# V4750   12.0      14.0      15.0        ...     35400.0   40000.0   40380.0   \
# V06111                                  ...
# Sim            0         6         4    ...            0         2         5
# Não           15        14        57    ...            1         1         0
#
# V4750   45000.0   46000.0   54424.0   60000.0   71666.0   107000.0  150000.0
# V06111
# Sim            4         2         2         2         3         2         1
# Não            1         0         0         0         0         0         0
#
# [2 rows x 4068 columns]

# %%
pd.crosstab([dados.V06111, dados.V4745],dados.V4750,  margins=True)
# Out:
# V4750                                          0.0  5.0  6.0  7.0  8.0  10.0  \
# V06111 V4745
# Sim    Sem instrução                            32    0    1    0    0     0
#        Fundamental incompleto ou equivalente   429    0    0    0    6     2
#        Fundamental completo ou equivalente     215    0    0    0    0     2
#        Médio incompleto ou equivalente         231    0    0    0    1     3
#        Médio completo ou equivalente           547    0    0    1    5     0
#        Superior incompleto ou equivalente      153    0    0    0    0     0
#        Superior completo                       140    0    0    0    0     0
# Não    Sem instrução                           124    0    0    0    1     0
#        Fundamental incompleto ou equivalente   485    1    1    2    3     7
#        Fundamental completo ou equivalente     120    0    0    1    1     2
#        Médio incompleto ou equivalente          95    0    0    0    2     2
#        Médio completo ou equivalente           175    0    0    0    1     2
#        Superior incompleto ou equivalente        6    0    0    0    1     0
#        Superior completo                        14    0    0    0    0     0
# All                                           2766    1    2    4   21    20
#
# V4750                                         11.0  12.0  14.0  15.0   ...    \
# V06111 V4745                                                           ...
# Sim    Sem instrução                             0     0     0     0   ...
#        Fundamental incompleto ou equivalente     2     0     3     2   ...
#        Fundamental completo ou equivalente       1     0     1     1   ...
#        Médio incompleto ou equivalente           0     0     1     0   ...
#        Médio completo ou equivalente             1     0     1     1   ...
#        Superior incompleto ou equivalente        1     0     0     0   ...
#        Superior completo                         1     0     0     0   ...
# Não    Sem instrução                             0     5     2    10   ...
#        Fundamental incompleto ou equivalente     4     7     7    38   ...
#        Fundamental completo ou equivalente       1     0     2     7   ...
#        Médio incompleto ou equivalente           1     3     1     0   ...
#        Médio completo ou equivalente             2     0     2     2   ...
#        Superior incompleto ou equivalente        0     0     0     0   ...
#        Superior completo                         0     0     0     0   ...
# All                                             14    15    20    61   ...
#
# V4750                                         40000.0  40380.0  45000.0  \
# V06111 V4745
# Sim    Sem instrução                                0        0        0
#        Fundamental incompleto ou equivalente        0        1        0
#        Fundamental completo ou equivalente          0        0        0
#        Médio incompleto ou equivalente              0        1        3
#        Médio completo ou equivalente                0        3        1
#        Superior incompleto ou equivalente           0        0        0
#        Superior completo                            2        0        0
# Não    Sem instrução                                0        0        0
#        Fundamental incompleto ou equivalente        0        0        1
#        Fundamental completo ou equivalente          0        0        0
#        Médio incompleto ou equivalente              0        0        0
#        Médio completo ou equivalente                1        0        0
#        Superior incompleto ou equivalente           0        0        0
#        Superior completo                            0        0        0
# All                                                 3        5        5
#
# V4750                                         46000.0  54424.0  60000.0  \
# V06111 V4745
# Sim    Sem instrução                                0        0        0
#        Fundamental incompleto ou equivalente        1        0        0
#        Fundamental completo ou equivalente          1        1        0
#        Médio incompleto ou equivalente              0        0        1
#        Médio completo ou equivalente                0        0        1
#        Superior incompleto ou equivalente           0        0        0
#        Superior completo                            0        1        0
# Não    Sem instrução                                0        0        0
#        Fundamental incompleto ou equivalente        0        0        0
#        Fundamental completo ou equivalente          0        0        0
#        Médio incompleto ou equivalente              0        0        0
#        Médio completo ou equivalente                0        0        0
#        Superior incompleto ou equivalente           0        0        0
#        Superior completo                            0        0        0
# All                                                 2        2        2
#
# V4750                                         71666.0  107000.0  150000.0  \
# V06111 V4745
# Sim    Sem instrução                                0         0         0
#        Fundamental incompleto ou equivalente        1         0         0
#        Fundamental completo ou equivalente          0         0         0
#        Médio incompleto ou equivalente              0         0         0
#        Médio completo ou equivalente                0         1         0
#        Superior incompleto ou equivalente           0         0         0
#        Superior completo                            2         1         1
# Não    Sem instrução                                0         0         0
#        Fundamental incompleto ou equivalente        0         0         0
#        Fundamental completo ou equivalente          0         0         0
#        Médio incompleto ou equivalente              0         0         0
#        Médio completo ou equivalente                0         0         0
#        Superior incompleto ou equivalente           0         0         0
#        Superior completo                            0         0         0
# All                                                 3         2         1
#
# V4750                                            All
# V06111 V4745
# Sim    Sem instrução                            1965
#        Fundamental incompleto ou equivalente   39044
#        Fundamental completo ou equivalente     16938
#        Médio incompleto ou equivalente         16663
#        Médio completo ou equivalente           56770
#        Superior incompleto ou equivalente      13657
#        Superior completo                       27717
# Não    Sem instrução                           23254
#        Fundamental incompleto ou equivalente   66397
#        Fundamental completo ou equivalente     12953
#        Médio incompleto ou equivalente          5436
#        Médio completo ou equivalente           17053
#        Superior incompleto ou equivalente        771
#        Superior completo                        2250
# All                                           300868
#
# [15 rows x 4069 columns]

# %%
faixa = range(10,7000,500)
RENDA_cat = pd.cut(dados.V4750, bins=faixa)
RENDA_cat.value_counts(sort=False, normalize=True)*100
plot = dados.V4750.plot.hist(bins=faixa,title='Dispersão de rendas', figsize=(6, 6), alpha=0.9)
plt.ylabel('Frequência absoluta')
plt.xlabel('renda (em reais)')
plt.plot()

ct1 = pd.crosstab(dados.V06111, RENDA_cat)
ct1.plot(kind='bar', color=('red','blue','green','yellow', 'salmon'),figsize=(20, 5))
plt.ylabel('Frequência Absoluta')
plt.title("Nivel de Ensino pelo uso de Internet \nem um período de 12 mêses")
plt.plot()
